# %% [markdown]
# <h2 style="color:green" align="center">Predicting if a person would buy life insurnace based on his age using logistic regression</h2>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/drive/MyDrive/Makeen 2025 - Data Science Stream/Machine Learning Material/ML Slides/Shared ML Slides/Shared ML Codes/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 23   45
# 25   54
# 12   27
# 18   19
# 0    22
# 6    55

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 23   45
# 25   54
# 12   27
# 18   19
# 0    22
# 6    55

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.21000984, 0.78999016],
#        [0.06246432, 0.93753568],
#        [0.80887556, 0.19112444],
#        [0.93539994, 0.06460006],
#        [0.90127697, 0.09872303],
#        [0.05404315, 0.94595685]])

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
y_predicted
# Out:
# array([1, 1, 0, 0, 0, 1])

# %%
X_test
# Out:
#     age
# 23   45
# 25   54
# 12   27
# 18   19
# 0    22
# 6    55

# %% [markdown]
# **model.coef_ indicates value of m in y=m*x + b equation**

# %%
model.coef_
# Out:
# array([[0.1537548]])

# %% [markdown]
# **model.intercept_ indicates value of b in y=m*x + b equation**

# %%
model.intercept_
# Out:
# array([-5.59410004])

# %% [markdown]
# **Lets defined sigmoid function now and do the math with hand**

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age):
    z = 0.042 * age - 1.53 # 0.04150133 ~ 0.042 and -1.52726963 ~ -1.53
    y = sigmoid(z)
    return y

# %%
age = 35
prediction_function(age)
# Out:
# 0.4850044983805899

# %% [markdown]
# **0.485 is less than 0.5 which means person with 35 age will *not* buy insurance**

# %%
age = 43
prediction_function(age)
# Out:
# 0.568565299077705

# %% [markdown]
# **0.485 is more than 0.5 which means person with 43 will buy the insurance**

# %% [markdown]
# <h2 style="color:purple">Exercise</h2>
#
# Download employee retention dataset from here: https://www.kaggle.com/giripujar/hr-analytics.
# 1. Now do some exploratory data analysis to figure out which variables have direct and clear impact on employee retention (i.e. whether they leave the company or continue to work)
# 2. Plot bar charts showing impact of employee salaries on retention
# 3. Plot bar charts showing corelation between department and employee retention
# 4. Now build logistic regression model using variables that were narrowed down in step 1
# 5. Measure the accuracy of the model

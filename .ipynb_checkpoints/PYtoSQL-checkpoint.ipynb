# %%
pip install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import glob
import os
path = "C:\\Users\\USER PC\\OneDrive\\Desktop\\Advance python\\csv"
all_files = glob.glob(os.path.join("C:\\Users\\USER PC\\OneDrive\\Desktop\\Advance python\\csv", "*.csv"))
df_list = []
for filename in all_files:
 df = pd.read_csv(filename, index_col=None, header=0)
 df_list.append(df) 
merged_df = pd.concat(df_list, axis=0, ignore_index=True)
merged_df.to_csv("merged_output.csv", index=False, encoding='utf-8')
print(" merged_output.csv")
# Out:
#  merged_output.csv

# %%
import pandas as pd
import pymysql
from tqdm import tqdm

# %%
import pymysql

connection = pymysql.connect(
    host="localhost",
    user="root",
    password="CODE//muradi",   # عدّلي إذا تغيرت
    charset="utf8mb4",
    cursorclass=pymysql.cursors.Cursor
)

cursor = connection.cursor() #الوسيط بين البايثون والداتابايس

# %%
cursor.execute("""
   CREATE TABLE IF NOT EXISTS PRODUCT (
    prid INT AUTO_INCREMENT PRIMARY KEY
    ProductName VARCHAR(20) UNIQUE   
    

);
""")
connection.commit()
print("ok")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 cursor.execute("""
#       2    CREATE TABLE IF NOT EXISTS PRODUCT (
#       3     prid INT AUTO_INCREMENT PRIMARY KEY
#       4     ProductName VARCHAR(20) UNIQUE
#       5
#       6
#       7 );
#       8 """)
#       9 connection.commit()
#      10 print("ok")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# ...

# %%
cursor.execute("""
    CREATE TABLE IF NOT EXISTS CUSTOMER (
    id INT AUTO_INCREMENT PRIMARY KEY 
    

);
""")
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 cursor.execute("""
#       2     CREATE TABLE IF NOT EXISTS CUSTOMER (
#       3     id INT AUTO_INCREMENT PRIMARY KEY
#       4
#       5
#       6 );
#       7 """)
#       8 connection.commit()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# ...

# %%
cursor.execute("""
   CREATE TABLE IF NOT EXISTS STORE (
    STOREID INT AUTO_INCREMENT PRIMARY KEY
    
    

);
""")
connection.commit()

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS SALES (
    SALEID INT AUTO_INCREMENT PRIMARY KEY,
    SALEDATE DATETIME,
    STOREID VARCHAR(50),
    CUSTOMERID VARCHAR(50),
    PRODUCTID INT,
    QTY INT,
    TOTALPRICE FLOAT,
    CURRENCYTYPE VARCHAR(50),

    FOREIGN KEY (CUSTOMERID) REFERENCES CUSTOMER(CUSTOMERID),
    FOREIGN KEY (PRODUCTID) REFERENCES PRODUCT(PRODUCTID),
    FOREIGN KEY (STOREID) REFERENCES STORE(STOREID)
);
""")
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cursor.execute("""
#       2 CREATE TABLE IF NOT EXISTS SALES (
#       3     SALEID INT AUTO_INCREMENT PRIMARY KEY,
#       4     SALEDATE DATETIME,
#       5     STOREID VARCHAR(50),
#       6     CUSTOMERID VARCHAR(50),
#       7     PRODUCTID INT,
#       8     QTY INT,
#       9     TOTALPRICE FLOAT,
#      10     CURRENCYTYPE VARCHAR(50),
#      11
#      12     FOREIGN KEY (CUSTOMERID) REFERENCES CUSTOMER(CUSTOMERID),
#      13     FOREIGN KEY (PRODUCTID) REFERENCES PRODUCT(PRODUCTID),
#      14     FOREIGN KEY (STOREID) REFERENCES STORE(STOREID)
#      15 );
#      16 """)
#      17 connection.commit()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# ...

# %%
CREATE TABLE IF NOT EXISTS SALES (
    SALEID INT AUTO_INCREMENT PRIMARY KEY,
    SALEDATE DATETIME,
    STOREID VARCHAR(50),
    CUSTOMERID VARCHAR(50),
    PRODUCTID INT,
    QTY INT,
    TOTALPRICE FLOAT,
    CURRENCYTYPE VARCHAR(50),

    FOREIGN KEY (CUSTOMERID) REFERENCES CUSTOMER(CUSTOMERID),
    FOREIGN KEY (PRODUCTID) REFERENCES PRODUCT(PRODUCTID),
    FOREIGN KEY (STOREID) REFERENCES STORE(STOREID)
);

# %%
products = merged_df["PRODUCTNAME"].unique()

for p in products:
    cursor.execute("""
        INSERT IGNORE INTO Products (PRODUCTNAME)
        VALUES (%s)
    """, (p,))
conn.commit()
print("Data is loaded sucssful")





customers = merged_df["CUSTOMERID"].unique()

for c in customers:
    cursor.execute("""
        INSERT IGNORE INTO Customers (CUSTOMERID)
        VALUES (%s)
    """, (c,))
conn.commit()
print("Data is loaded sucssful")




stores =merged_df["STOREID"].unique()

for s in stores:
    cursor.execute("""
        INSERT IGNORE INTO Stores (STOREID)
        VALUES (%s)
    """, (s,))
conn.commit()
print("Data is loaded sucssful")


for _, row in merged_df.iterrows():
    cursor.execute("""
        INSERT INTO Sales
        (PRODUCTID, CUSTOMERID,STOREID, QTY, CURRENCYTYPE, TOTALPRICE, SALEDATE)
        VALUES (%s, %s, %s, %s, %s, %s, %s)
    """,
    (
        prod_map[row["PRODUCTID"]],
        row["CUSTOMERID"],
        row["STOREID"],
        row["QTY"],
        row["CURRENCYTYPE"],
        row["TOTALPRICE"],
        row["SALEDATE"]
    ))

conn.commit()

cursor.close()
conn.close()

print("Data is loaded sucssful")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PRODUCTNAME'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 products = merged_df["PRODUCTNAME"].unique()
# ...

# %%
STORE = pymysql.connect(
DB_USER = 'root'  ,      # e.g., 'root'
DB_PASSWORD = 'CODE//muradi', # e.g., 'mysecretpassword'
DB_HOST = 'localhost' ,             # e.g., '127.0.0.1' or server IP
DB_PORT = '3306' ,                  # Standard MySQL port
DB_NAME = 'STORE' 
)
cursor = central_db_connection.cursor()

# -----------------------------------------
# 2) تحميل جدول Products
# -----------------------------------------
products = df["ProductName"].unique()

for p in products:
    cursor.execute("""
        INSERT IGNORE INTO Products (ProductName)
        VALUES (%s)
    """, (p,))
conn.commit()

# عمل خريطة: ProductName → ProductID
cursor.execute("SELECT ProductID, ProductName FROM Products")
prod_map = {name: pid for pid, name in cursor.fetchall()}

# -----------------------------------------
# 3) تحميل جدول Customers
# -----------------------------------------
customers = df["CustomerID"].unique()

for c in customers:
    cursor.execute("""
        INSERT IGNORE INTO Customers (CustomerID)
        VALUES (%s)
    """, (c,))
conn.commit()

# -----------------------------------------
# 4) تحميل جدول Stores
# -----------------------------------------
stores = df["StoreID"].unique()

for s in stores:
    cursor.execute("""
        INSERT IGNORE INTO Stores (StoreID)
        VALUES (%s)
    """, (s,))
conn.commit()

# -----------------------------------------
# 5) تحميل جدول Sales
# -----------------------------------------
for _, row in df.iterrows():
    cursor.execute("""
        INSERT INTO Sales
        (ProductID, CustomerID, StoreID, Qty, UnitPrice_OMR, TotalPrice, SaleDate)
        VALUES (%s, %s, %s, %s, %s, %s, %s)
    """,
    (
        prod_map[row["ProductName"]],
        row["CustomerID"],
        row["StoreID"],
        row["Qty"],
        row["UnitPrice_OMR"],
        row["TotalPrice"],
        row["SaleDate"]
    ))

conn.commit()

cursor.close()
conn.close()

print("Data is loaded sucssful")

central_db_connection.commit()
central_db_connection.close()

print("Data successfully stored in the central MySQL database.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 STORE = pymysql.connect(
#       2 DB_USER = 'root'  ,      # e.g., 'root'
#       3 DB_PASSWORD = 'CODE//muradi', # e.g., 'mysecretpassword'
#       4 DB_HOST = 'localhost' ,             # e.g., '127.0.0.1' or server IP
#       5 DB_PORT = '3306' ,                  # Standard MySQL port
#       6 DB_NAME = 'STORE'
#       7 )
#       8 cursor = central_db_connection.cursor()
#      10 # -----------------------------------------
#      11 # 2) تحميل جدول Products
#      12 # -----------------------------------------
#
# TypeError: Connection.__init__() got an unexpected keyword argument 'DB_USER'
